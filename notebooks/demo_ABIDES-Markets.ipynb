# %% [markdown]
# This is a tutorial for basic use of abides_markets simulation.
# It uses the simulator directly without the OpenAI Gym interface

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from abides_core import abides
from abides_core.utils import parse_logs_df, ns_date, str_to_ns, fmt_ts
from abides_markets.configs import rmsc04
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 7
#       5 from abides_core import abides
#       6 from abides_core.utils import parse_logs_df, ns_date, str_to_ns, fmt_ts
# ----> 7 from abides_markets.configs import rmsc04
#
# File <frozen zipimport>:259, in load_module(self, fullname)
#
# File /opt/anaconda3/envs/pendle/lib/python3.9/site-packages/abides_markets-0.0.0-py3.9.egg/abides_markets/configs/rmsc04.py:15
#      12 import pandas as pd
#      14 from abides_core.utils import get_wake_time, str_to_ns
# ---> 15 from abides_markets.agents import (
#      16     ExchangeAgent,
#      17     NoiseAgent,
#      18     ValueAgent,
#      19     AdaptiveMarketMakerAgent,
#      20     MomentumAgent,
#      21 )
#      22 from abides_markets.models import OrderSizeModel
#      23 from abides_markets.oracles import SparseMeanRevertingOracle
#
# ImportError: cannot import name 'AdaptiveMarketMakerAgent' from 'abides_markets.agents' (/opt/anaconda3/envs/pendle/lib/python3.9/site-packages/abides_markets-0.0.0-py3.9.egg/abides_markets/agents/__init__.py)

# %% [markdown]
# ## Build runnable configuration

# %% [markdown]
# Here we are generating/building a config from the config file rmsc04.
# The config object is a dictionnary containing key elements like, start time, end time, agents to be used, latency and computation delay models.

# %%
config = rmsc04.build_config()
# Out:
# /opt/anaconda3/envs/pendle/lib/python3.9/site-packages/abides_core-0.0.0-py3.9.egg/abides_core/utils.py:97: FutureWarning: 'S' is deprecated and will be removed in a future version. Please use 's' instead of 'S'.

# %%
config.keys()
# Out:
# dict_keys(['seed', 'start_time', 'stop_time', 'agents', 'agent_latency_model', 'default_computation_delay', 'custom_properties', 'random_state_kernel', 'stdout_log_level'])

# %% [markdown]
# ## Running simulation

# %% [markdown]
# Once the config is ready it can be run using the abides runner function.
# It instanciates a simulation kernel, runs the configuration and returns an end_state that mostly contains pointers to the different agent objects.
# The agents are in their final state, their internal variables can be accessed to extract informations of interests like logs.

# %%
end_state = abides.run( config )
# Out:
# [11985] INFO abides Simulation Start Time: 2024-10-14 19:00:10.835103
# [11985] INFO abides_core.kernel --- Simulation time: 2021-02-05 00:00:00, messages processed: 0, wallclock elapsed: 0.00s ---
# [11985] INFO abides_core.kernel Event Queue elapsed: 0:00:00.396550, messages: 17,053, messages per second: 43003.4
# [11985] INFO abides_core.kernel Mean ending value by agent type:
# [11985] INFO abides_core.kernel NoiseAgent: 20
# [11985] INFO abides_core.kernel ValueAgent: -820
# [11985] INFO abides_core.kernel AdaptivePOVMarketMakerAgent: 0
# [11985] INFO abides_core.kernel MomentumAgent: 5276
# [11985] INFO abides_core.kernel Simulation ending!
# [11985] INFO abides Simulation End Time: 2024-10-14 19:00:11.486243
# [11985] INFO abides Time taken to run simulation: 0:00:00.651140

# %%
random_agent = end_state["agents"][0]

# %%
random_agent.log
# Out:
# [(0, 'AGENT_TYPE', 'ExchangeAgent'),
#  (1612483200000005413,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23691)),
#  (1612483200000005463,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23692)),
#  (1612483200000008196,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24115)),
#  (1612483200000008196,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24116)),
#  (1612483200000014556,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23723)),
#  (1612483200000014556,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23724)),
#  (1612483200000016412,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23479)),
#  (1612483200000016412,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23480)),
#  (1612483200000017218,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24413)),
#  (1612483200000017218,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24414)),
#  (1612483200000023443,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23293)),
#  (1612483200000023443,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23294)),
#  (1612483200000052083,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23647)),
#  (1612483200000052083,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23648)),
#  (1612483200000052302,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23801)),
#  (1612483200000052302,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23802)),
#  (1612483200000063972,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23707)),
#  (1612483200000063972,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23708)),
#  (1612483200000067092,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23975)),
#  (1612483200000067092,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23976)),
#  (1612483200000067995,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24451)),
#  (1612483200000067995,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24452)),
#  (1612483200000068138,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23649)),
#  (1612483200000068138,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23650)),
#  (1612483200000076464,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24615)),
#  (1612483200000076464,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24616)),
#  (1612483200000082938,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24647)),
#  (1612483200000082938,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24648)),
#  (1612483200000083206,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23927)),
#  (1612483200000083206,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23928)),
#  (1612483200000083253,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24501)),
#  (1612483200000083253,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24502)),
#  (1612483200000085604,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24979)),
#  (1612483200000085604,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24980)),
#  (1612483200000085911,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23591)),
#  (1612483200000085911,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23592)),
#  (1612483200000092500,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24009)),
#  (1612483200000092500,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24010)),
#  (1612483200000100342,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24595)),
#  (1612483200000100342,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24596)),
#  (1612483200000110486,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24833)),
#  (1612483200000110486,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24834)),
#  (1612483200000114713,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23965)),
#  (1612483200000114713,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23966)),
#  (1612483200000120416,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24723)),
#  (1612483200000120416,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24724)),
#  (1612483200000121434,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22797)),
#  (1612483200000121434,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22798)),
#  (1612483200000124956,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24301)),
#  (1612483200000124956,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24302)),
#  (1612483200000125030,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22921)),
#  (1612483200000125030,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22922)),
#  (1612483200000131390,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23317)),
#  (1612483200000131390,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23318)),
#  (1612483200000146706,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24513)),
#  (1612483200000146706,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24514)),
#  (1612483200000148271,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24321)),
#  (1612483200000148271,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24322)),
#  (1612483200000149172,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23199)),
#  (1612483200000149172,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23200)),
#  (1612483200000153517,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22805)),
#  (1612483200000153517,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22806)),
#  (1612483200000159343,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24993)),
#  (1612483200000159343,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24994)),
#  (1612483200000173886,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23671)),
#  (1612483200000173886,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23672)),
#  (1612483200000188954,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23155)),
#  (1612483200000188954,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23156)),
#  (1612483200000192726,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23663)),
#  (1612483200000192726,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23664)),
#  (1612483200000193317,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23677)),
#  (1612483200000193317,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23678)),
#  (1612483200000205571,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23961)),
#  (1612483200000205571,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23962)),
#  (1612483200000217399,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23991)),
#  (1612483200000217399,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23992)),
#  (1612483200000225732,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23745)),
#  (1612483200000225732,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23746)),
#  (1612483200000247870,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24427)),
#  (1612483200000247870,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24428)),
#  (1612483200000256030,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23857)),
#  (1612483200000256030,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23858)),
#  (1612483200000262252,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23163)),
#  (1612483200000262252,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23164)),
#  (1612483200000263086,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23537)),
#  (1612483200000263086,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23538)),
#  (1612483200000266616,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24017)),
#  (1612483200000266616,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24018)),
#  (1612483200000279792,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24699)),
#  (1612483200000279792,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24700)),
#  (1612483200000281246,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24521)),
#  (1612483200000281246,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24522)),
#  (1612483200000284111,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24447)),
#  (1612483200000284111,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24448)),
#  (1612483200000292746,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24191)),
#  (1612483200000292746,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24192)),
#  (1612483200000294754,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24393)),
#  (1612483200000294754,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24394)),
#  (1612483200000302257,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23809)),
#  (1612483200000302257,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23810)),
#  (1612483200000306593,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24601)),
#  (1612483200000306593,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24602)),
#  (1612483200000321823,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23977)),
#  (1612483200000321823,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23978)),
#  (1612483200000322000,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22985)),
#  (1612483200000322000,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22986)),
#  (1612483200000330823,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23583)),
#  (1612483200000330823,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23584)),
#  (1612483200000334375,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23487)),
#  (1612483200000334375,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23488)),
#  (1612483200000349263,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24841)),
#  (1612483200000349263,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24842)),
#  (1612483200000352164,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23751)),
#  (1612483200000352164,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23752)),
#  (1612483200000369963,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24989)),
#  (1612483200000369963,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24990)),
#  (1612483200000380280,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22883)),
#  (1612483200000380280,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22884)),
#  (1612483200000383859,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24237)),
#  (1612483200000383859,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24238)),
#  (1612483200000385152,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24355)),
#  (1612483200000385152,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24356)),
#  (1612483200000386182,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24177)),
#  (1612483200000386182,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24178)),
#  (1612483200000387286,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22981)),
#  (1612483200000387286,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22982)),
#  (1612483200000389254,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24019)),
#  (1612483200000389254,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24020)),
#  (1612483200000390154,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24625)),
#  (1612483200000390154,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24626)),
#  (1612483200000406205,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24643)),
#  (1612483200000406205,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24644)),
#  (1612483200000427385,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23379)),
#  (1612483200000427385,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23380)),
#  (1612483200000442165,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22885)),
#  (1612483200000442165,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22886)),
#  (1612483200000446317,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24197)),
#  (1612483200000446317,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24198)),
#  (1612483200000446890,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24331)),
#  (1612483200000446890,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24332)),
#  (1612483200000447586,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24071)),
#  (1612483200000447586,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24072)),
#  (1612483200000451984,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24987)),
#  (1612483200000451984,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24988)),
#  (1612483200000461232,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23893)),
#  (1612483200000461232,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23894)),
#  (1612483200000477649,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22845)),
#  (1612483200000477649,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22846)),
#  (1612483200000485293,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24507)),
#  (1612483200000485293,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24508)),
#  (1612483200000487270,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24611)),
#  (1612483200000487270,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24612)),
#  (1612483200000488607,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23859)),
#  (1612483200000488607,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23860)),
#  (1612483200000506782,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24881)),
#  (1612483200000506782,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24882)),
#  (1612483200000509187,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24801)),
#  (1612483200000509187,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24802)),
#  (1612483200000515042,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22849)),
#  (1612483200000515042,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22850)),
#  (1612483200000517465,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22815)),
#  (1612483200000517465,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22816)),
#  (1612483200000523163,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23711)),
#  (1612483200000523163,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23712)),
#  (1612483200000524952,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24337)),
#  (1612483200000524952,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24338)),
#  (1612483200000524985,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23619)),
#  (1612483200000524985,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23620)),
#  (1612483200000526545,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22829)),
#  (1612483200000526545,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22830)),
#  (1612483200000529655,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24971)),
#  (1612483200000529655,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24972)),
#  (1612483200000531867,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23885)),
#  (1612483200000531867,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23886)),
#  (1612483200000541320,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23599)),
#  (1612483200000541320,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23600)),
#  (1612483200000571507,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23493)),
#  (1612483200000571507,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23494)),
#  (1612483200000572887,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24155)),
#  (1612483200000572887,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24156)),
#  (1612483200000575757,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23553)),
#  (1612483200000575757,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23554)),
#  (1612483200000578021,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23335)),
#  (1612483200000578021,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23336)),
#  (1612483200000585816,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23525)),
#  (1612483200000585816,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23526)),
#  (1612483200000587002,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24997)),
#  (1612483200000587002,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24998)),
#  (1612483200000597633,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24007)),
#  (1612483200000597633,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24008)),
#  (1612483200000602394,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23825)),
#  (1612483200000602394,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23826)),
#  (1612483200000602928,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24965)),
#  (1612483200000602928,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24966)),
#  (1612483200000614138,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23851)),
#  (1612483200000614138,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23852)),
#  (1612483200000615720,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23695)),
#  (1612483200000615720,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23696)),
#  (1612483200000618676,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24785)),
#  (1612483200000618676,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24786)),
#  (1612483200000622081,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23353)),
#  (1612483200000622081,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23354)),
#  (1612483200000636411,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24797)),
#  (1612483200000636411,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24798)),
#  (1612483200000639126,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24111)),
#  (1612483200000639126,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24112)),
#  (1612483200000639955,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24051)),
#  (1612483200000639955,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24052)),
#  (1612483200000653397,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23407)),
#  (1612483200000653397,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23408)),
#  (1612483200000653680,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24575)),
#  (1612483200000653680,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24576)),
#  (1612483200000658594,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23003)),
#  (1612483200000658594,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23004)),
#  (1612483200000662016,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23841)),
#  (1612483200000662016,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23842)),
#  (1612483200000663314,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24309)),
#  (1612483200000663314,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24310)),
#  (1612483200000667506,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23497)),
#  (1612483200000667506,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23498)),
#  (1612483200000668843,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24483)),
#  (1612483200000668843,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24484)),
#  (1612483200000682215,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23791)),
#  (1612483200000682215,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23792)),
#  (1612483200000692666,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24349)),
#  (1612483200000692666,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24350)),
#  (1612483200000695215,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23229)),
#  (1612483200000695215,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23230)),
#  (1612483200000700095,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24569)),
#  (1612483200000700095,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24570)),
#  (1612483200000700742,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23625)),
#  (1612483200000700742,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23626)),
#  (1612483200000702397,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24867)),
#  (1612483200000702397,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24868)),
#  (1612483200000702788,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24525)),
#  (1612483200000702788,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24526)),
#  (1612483200000711565,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24487)),
#  (1612483200000711565,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24488)),
#  (1612483200000714825,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23653)),
#  (1612483200000714825,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23654)),
#  (1612483200000722028,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23783)),
#  (1612483200000722028,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23784)),
#  (1612483200000725027,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23595)),
#  (1612483200000725027,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23596)),
#  (1612483200000731525,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23291)),
#  (1612483200000731525,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23292)),
#  (1612483200000736990,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24535)),
#  (1612483200000736990,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24536)),
#  (1612483200000742197,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22835)),
#  (1612483200000742197,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22836)),
#  (1612483200000751072,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23921)),
#  (1612483200000751072,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23922)),
#  (1612483200000757211,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24255)),
#  (1612483200000757211,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24256)),
#  (1612483200000760126,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22927)),
#  (1612483200000760126,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22928)),
#  (1612483200000765577,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24013)),
#  (1612483200000765577,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24014)),
#  (1612483200000784854,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22865)),
#  (1612483200000784854,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22866)),
#  (1612483200000789943,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23281)),
#  (1612483200000789943,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23282)),
#  (1612483200000801729,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24701)),
#  (1612483200000801729,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24702)),
#  (1612483200000813404,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23467)),
#  (1612483200000813404,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23468)),
#  (1612483200000814343,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23227)),
#  (1612483200000814343,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23228)),
#  (1612483200000814558,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23015)),
#  (1612483200000814558,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23016)),
#  (1612483200000820590,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24137)),
#  (1612483200000820590,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24138)),
#  (1612483200000820704,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24389)),
#  (1612483200000820704,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24390)),
#  (1612483200000839695,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22879)),
#  (1612483200000839695,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22880)),
#  (1612483200000840231,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23699)),
#  (1612483200000840231,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23700)),
#  (1612483200000846272,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24305)),
#  (1612483200000846272,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24306)),
#  (1612483200000848684,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23119)),
#  (1612483200000848684,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23120)),
#  (1612483200000849164,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24133)),
#  (1612483200000849164,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24134)),
#  (1612483200000851474,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24277)),
#  (1612483200000851474,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24278)),
#  (1612483200000851849,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23741)),
#  (1612483200000851849,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23742)),
#  (1612483200000852890,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23289)),
#  (1612483200000852890,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23290)),
#  (1612483200000856237,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24675)),
#  (1612483200000856237,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24676)),
#  (1612483200000859899,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24497)),
#  (1612483200000859899,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24498)),
#  (1612483200000862460,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23585)),
#  (1612483200000862460,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23586)),
#  (1612483200000870111,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22867)),
#  (1612483200000870111,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22868)),
#  (1612483200000892459,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23901)),
#  (1612483200000892459,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23902)),
#  (1612483200000897514,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23071)),
#  (1612483200000897514,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23072)),
#  (1612483200000899696,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23999)),
#  (1612483200000899696,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24000)),
#  (1612483200000906448,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24549)),
#  (1612483200000906448,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24550)),
#  (1612483200000919684,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23709)),
#  (1612483200000919684,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23710)),
#  (1612483200000920364,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24405)),
#  (1612483200000920364,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24406)),
#  (1612483200000934203,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23225)),
#  (1612483200000934203,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23226)),
#  (1612483200000945217,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24453)),
#  (1612483200000945217,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24454)),
#  (1612483200000954688,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23305)),
#  (1612483200000954688,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23306)),
#  (1612483200000954891,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23167)),
#  (1612483200000954891,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23168)),
#  (1612483200000958427,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23735)),
#  (1612483200000958427,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23736)),
#  (1612483200000960307,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22807)),
#  (1612483200000960307,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22808)),
#  (1612483200000961858,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24577)),
#  (1612483200000961858,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24578)),
#  (1612483200000966303,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23545)),
#  (1612483200000966303,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23546)),
#  (1612483200000968312,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23969)),
#  (1612483200000968312,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23970)),
#  (1612483200000969500,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24587)),
#  (1612483200000969500,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24588)),
#  (1612483200000977916,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23705)),
#  (1612483200000977916,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23706)),
#  (1612483200000980644,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22877)),
#  (1612483200000980644,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22878)),
#  (1612483200000983275,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23759)),
#  (1612483200000983275,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23760)),
#  (1612483200000988191,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23437)),
#  (1612483200000988191,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23438)),
#  (1612483200001001665,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23173)),
#  (1612483200001001665,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23174)),
#  (1612483200001014867,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23037)),
#  (1612483200001014867,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23038)),
#  (1612483200001019836,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24767)),
#  (1612483200001019836,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24768)),
#  (1612483200001036419,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24441)),
#  (1612483200001036419,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24442)),
#  (1612483200001037402,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23767)),
#  (1612483200001037402,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23768)),
#  (1612483200001040407,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22957)),
#  (1612483200001040407,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22958)),
#  (1612483200001043643,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24703)),
#  (1612483200001043643,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24704)),
#  (1612483200001048633,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24813)),
#  (1612483200001048633,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24814)),
#  (1612483200001048634,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24757)),
#  (1612483200001048634,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24758)),
#  (1612483200001062688,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23241)),
#  (1612483200001062688,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23242)),
#  (1612483200001067341,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24257)),
#  (1612483200001067341,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24258)),
#  (1612483200001077484,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23985)),
#  (1612483200001077484,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23986)),
#  (1612483200001087957,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22771)),
#  (1612483200001087957,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22772)),
#  (1612483200001093232,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23073)),
#  (1612483200001093232,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23074)),
#  (1612483200001100250,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24481)),
#  (1612483200001100250,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24482)),
#  (1612483200001102879,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23637)),
#  (1612483200001102879,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23638)),
#  (1612483200001103316,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23075)),
#  (1612483200001103316,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23076)),
#  (1612483200001107072,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24379)),
#  (1612483200001107072,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24380)),
#  (1612483200001114266,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23731)),
#  (1612483200001114266,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23732)),
#  (1612483200001115985,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24533)),
#  (1612483200001115985,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24534)),
#  (1612483200001120392,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24499)),
#  (1612483200001120392,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24500)),
#  (1612483200001130564,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24005)),
#  (1612483200001130564,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24006)),
#  (1612483200001133343,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23205)),
#  (1612483200001133343,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23206)),
#  (1612483200001142721,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24163)),
#  (1612483200001142721,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24164)),
#  (1612483200001144555,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23733)),
#  (1612483200001144555,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23734)),
#  (1612483200001152448,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24857)),
#  (1612483200001152448,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24858)),
#  (1612483200001155475,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24649)),
#  (1612483200001155475,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24650)),
#  (1612483200001168148,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22875)),
#  (1612483200001168148,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22876)),
#  (1612483200001169913,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23157)),
#  (1612483200001169913,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23158)),
#  (1612483200001177694,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23297)),
#  (1612483200001177694,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23298)),
#  (1612483200001180094,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24041)),
#  (1612483200001180094,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24042)),
#  (1612483200001183818,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24695)),
#  (1612483200001183818,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24696)),
#  (1612483200001186860,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24391)),
#  (1612483200001186860,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24392)),
#  (1612483200001198419,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24519)),
#  (1612483200001198419,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24520)),
#  (1612483200001212590,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23541)),
#  (1612483200001212590,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23542)),
#  (1612483200001214620,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23739)),
#  (1612483200001214620,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23740)),
#  (1612483200001220448,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22999)),
#  (1612483200001220448,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23000)),
#  (1612483200001222430,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24143)),
#  (1612483200001222430,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24144)),
#  (1612483200001244267,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24089)),
#  (1612483200001244267,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24090)),
#  (1612483200001262197,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24653)),
#  (1612483200001262197,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24654)),
#  (1612483200001273089,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24629)),
#  (1612483200001273089,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24630)),
#  (1612483200001274161,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22941)),
#  (1612483200001274161,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22942)),
#  (1612483200001275080,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23409)),
#  (1612483200001275080,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23410)),
#  (1612483200001284417,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24769)),
#  (1612483200001284417,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24770)),
#  (1612483200001288398,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24887)),
#  (1612483200001288398,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24888)),
#  (1612483200001294097,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24755)),
#  (1612483200001294097,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24756)),
#  (1612483200001299307,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23397)),
#  (1612483200001299307,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23398)),
#  (1612483200001301345,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23725)),
#  (1612483200001301345,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23726)),
#  (1612483200001306070,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24435)),
#  (1612483200001306070,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24436)),
#  (1612483200001309078,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23559)),
#  (1612483200001309078,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23560)),
#  (1612483200001310662,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23429)),
#  (1612483200001310662,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23430)),
#  (1612483200001311518,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24637)),
#  (1612483200001311518,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24638)),
#  (1612483200001314131,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23721)),
#  (1612483200001314131,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23722)),
#  (1612483200001315365,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24241)),
#  (1612483200001315365,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24242)),
#  (1612483200001316873,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23891)),
#  (1612483200001316873,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23892)),
#  (1612483200001318383,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22791)),
#  (1612483200001318383,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22792)),
#  (1612483200001325424,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24471)),
#  (1612483200001325424,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24472)),
#  (1612483200001327458,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24429)),
#  (1612483200001327458,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24430)),
#  (1612483200001329019,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24715)),
#  (1612483200001329019,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24716)),
#  (1612483200001334744,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24845)),
#  (1612483200001334744,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24846)),
#  (1612483200001339322,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23269)),
#  (1612483200001339322,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23270)),
#  (1612483200001342047,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24313)),
#  (1612483200001342047,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24314)),
#  (1612483200001344961,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24589)),
#  (1612483200001344961,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24590)),
#  (1612483200001349531,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23197)),
#  (1612483200001349531,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23198)),
#  (1612483200001353815,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23209)),
#  (1612483200001353815,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23210)),
#  (1612483200001356149,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23183)),
#  (1612483200001356149,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23184)),
#  (1612483200001370285,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23425)),
#  (1612483200001370285,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23426)),
#  (1612483200001370566,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24683)),
#  (1612483200001370566,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24684)),
#  (1612483200001371178,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22887)),
#  (1612483200001371178,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22888)),
#  (1612483200001371664,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24093)),
#  (1612483200001371664,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24094)),
#  (1612483200001374338,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23191)),
#  (1612483200001374338,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23192)),
#  (1612483200001375705,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24107)),
#  (1612483200001375705,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24108)),
#  (1612483200001382408,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23867)),
#  (1612483200001382408,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23868)),
#  (1612483200001386644,
# ...
#  (1612483200003110513,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23109)),
#  (1612483200003110513,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23110)),
#  (1612483200003123950,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24303)),
#  (1612483200003123950,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24304)),
#  (1612483200003130555,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24919)),
#  (1612483200003130555,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24920)),
#  (1612483200003149670,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23761)),
#  (1612483200003149670,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23762)),
#  (1612483200003179553,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24883)),
#  (1612483200003179553,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24884)),
#  (1612483200003180880,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24207)),
#  (1612483200003180880,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24208)),
#  (1612483200003182310,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24851)),
#  (1612483200003182310,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24852)),
#  (1612483200003190136,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23311)),
#  (1612483200003190136,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23312)),
#  (1612483200003190969,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23729)),
#  (1612483200003190969,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23730)),
#  (1612483200003193892,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22859)),
#  (1612483200003193892,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22860)),
#  (1612483200003200683,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24439)),
#  (1612483200003200683,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24440)),
#  (1612483200003222605,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22947)),
#  (1612483200003222605,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22948)),
#  (1612483200003248665,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23615)),
#  (1612483200003248665,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23616)),
#  (1612483200003253512,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22861)),
#  (1612483200003253512,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22862)),
#  (1612483200003255529,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23771)),
#  (1612483200003255529,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23772)),
#  (1612483200003264282,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23235)),
#  (1612483200003264282,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23236)),
#  (1612483200003267331,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22777)),
#  (1612483200003267331,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22778)),
#  (1612483200003296057,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23275)),
#  (1612483200003296057,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23276)),
#  (1612483200003298801,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23133)),
#  (1612483200003298801,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23134)),
#  (1612483200003304771,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23171)),
#  (1612483200003304771,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23172)),
#  (1612483200003308298,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24141)),
#  (1612483200003308298,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24142)),
#  (1612483200003312612,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23789)),
#  (1612483200003312612,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23790)),
#  (1612483200003317937,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23823)),
#  (1612483200003317937,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23824)),
#  (1612483200003319958,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23185)),
#  (1612483200003319958,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23186)),
#  (1612483200003321055,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24976)),
#  (1612483200003321055,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24977)),
#  (1612483200003321055,
#   'BookImbalanceSubReqMsg',
#   BookImbalanceSubReqMsg(message_id=24978, symbol='ABM', cancel=False, min_imbalance=0.9)),
#  (1612483200003336076,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24489)),
#  (1612483200003336076,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24490)),
#  (1612483200003348650,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23959)),
#  (1612483200003348650,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23960)),
#  (1612483200003361338,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24685)),
#  (1612483200003361338,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24686)),
#  (1612483200003367400,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23105)),
#  (1612483200003367400,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23106)),
#  (1612483200003368274,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23469)),
#  (1612483200003368274,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23470)),
#  (1612483200003383051,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23513)),
#  (1612483200003383051,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23514)),
#  (1612483200003392575,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24229)),
#  (1612483200003392575,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24230)),
#  (1612483200003400136,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23321)),
#  (1612483200003400136,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23322)),
#  (1612483200003407354,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23009)),
#  (1612483200003407354,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23010)),
#  (1612483200003414363,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23881)),
#  (1612483200003414363,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23882)),
#  (1612483200003415355,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23141)),
#  (1612483200003415355,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23142)),
#  (1612483200003415643,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24917)),
#  (1612483200003415643,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24918)),
#  (1612483200003419650,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24101)),
#  (1612483200003419650,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24102)),
#  (1612483200003435284,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23391)),
#  (1612483200003435284,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23392)),
#  (1612483200003445930,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23669)),
#  (1612483200003445930,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23670)),
#  (1612483200003450345,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24807)),
#  (1612483200003450345,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24808)),
#  (1612483200003458227,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24789)),
#  (1612483200003458227,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24790)),
#  (1612483200003476064,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23779)),
#  (1612483200003476064,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23780)),
#  (1612483200003482821,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24691)),
#  (1612483200003482821,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24692)),
#  (1612483200003487479,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23223)),
#  (1612483200003487479,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23224)),
#  (1612483200003523447,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22959)),
#  (1612483200003523447,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22960)),
#  (1612483200003535998,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24727)),
#  (1612483200003535998,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24728)),
#  (1612483200003541391,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24861)),
#  (1612483200003541391,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24862)),
#  (1612483200003560816,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24873)),
#  (1612483200003560816,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24874)),
#  (1612483200003561142,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22997)),
#  (1612483200003561142,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22998)),
#  (1612483200003570978,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23207)),
#  (1612483200003570978,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23208)),
#  (1612483200003577290,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23773)),
#  (1612483200003577290,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23774)),
#  (1612483200003596075,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24899)),
#  (1612483200003596075,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24900)),
#  (1612483200003599331,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24909)),
#  (1612483200003599331,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24910)),
#  (1612483200003610763,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22783)),
#  (1612483200003610763,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22784)),
#  (1612483200003616410,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24707)),
#  (1612483200003616410,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24708)),
#  (1612483200003621787,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24045)),
#  (1612483200003621787,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24046)),
#  (1612483200003631139,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22943)),
#  (1612483200003631139,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22944)),
#  (1612483200003635616,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23265)),
#  (1612483200003635616,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23266)),
#  (1612483200003683884,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23611)),
#  (1612483200003683884,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23612)),
#  (1612483200003694834,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23945)),
#  (1612483200003694834,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23946)),
#  (1612483200003705357,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24243)),
#  (1612483200003705357,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24244)),
#  (1612483200003706343,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24609)),
#  (1612483200003706343,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24610)),
#  (1612483200003713777,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24605)),
#  (1612483200003713777,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24606)),
#  (1612483200003715929,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24485)),
#  (1612483200003715929,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24486)),
#  (1612483200003776272,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24213)),
#  (1612483200003776272,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24214)),
#  (1612483200003777539,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23813)),
#  (1612483200003777539,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23814)),
#  (1612483200003785342,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23655)),
#  (1612483200003785342,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23656)),
#  (1612483200003790766,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23315)),
#  (1612483200003790766,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23316)),
#  (1612483200003814046,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23093)),
#  (1612483200003814046,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23094)),
#  (1612483200003838196,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24329)),
#  (1612483200003838196,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24330)),
#  (1612483200003840308,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23853)),
#  (1612483200003840308,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23854)),
#  (1612483200003860611,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22973)),
#  (1612483200003860611,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22974)),
#  (1612483200003861034,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22831)),
#  (1612483200003861034,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22832)),
#  (1612483200003866073,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24743)),
#  (1612483200003866073,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24744)),
#  (1612483200003888496,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=22773)),
#  (1612483200003888496,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=22774)),
#  (1612483200003891068,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23897)),
#  (1612483200003891068,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23898)),
#  (1612483200003907527,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24677)),
#  (1612483200003907527,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24678)),
#  (1612483200003911246,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=24593)),
#  (1612483200003911246,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=24594)),
#  (1612483200003913320,
#   'MarketClosePriceRequestMsg',
#   MarketClosePriceRequestMsg(message_id=23113)),
#  (1612483200003913320,
#   'MarketHoursRequestMsg',
#   MarketHoursRequestMsg(message_id=23114)),
#  ...]

# %% [markdown]
# ## Retrieving results from end_state

# %% [markdown]
# By convention in abides_markets configuration the first agent is the exchange agent.
# It contains an order_book. By default it logs its history.

# %%
order_book = end_state["agents"][0].order_books["ABM"]

# %% [markdown]
# ### Order book history L1

# %% [markdown]
# L1 data snapshots for every tick can be extracted
# ( best bid and ask price and quantity )

# %%
L1 = order_book.get_L1_snapshots()

# %% [markdown]
# Here we plot the time series of the best bid and best ask price thoughout the simulation

# %%
best_bids = pd.DataFrame(L1["best_bids"],columns=["time","price","qty"])
best_asks = pd.DataFrame(L1["best_asks"],columns=["time","price","qty"])

## All times are in ns from 1970, remove the date component to put them in ns from midnight
best_bids["time"] = best_bids["time"].apply( lambda x: x - ns_date(x) )
best_asks["time"] = best_asks["time"].apply( lambda x: x - ns_date(x) )

plt.plot(best_bids.time,best_bids.price)
plt.plot(best_asks.time,best_asks.price)

band = 100
plt.ylim(100_000-band,100_000+band)

time_mesh = np.arange(
    str_to_ns("09:30:00"),
    str_to_ns("10:10:00"),
    1e9*60*10
)
_=plt.xticks(time_mesh, [ fmt_ts(time).split(" ")[1] for time in time_mesh], rotation=60 )

# %% [markdown]
# ### Order book history L2

# %% [markdown]
# L2 data snapshots for every tick can be extracted
# ( bids and asks price and quantity for every orderbook level. Here max depth logged is a parameter of the simulation and max number of levels we want to retrieve from the orderbook after the simulation is a parameter too)

# %%
L2 = order_book.get_L2_snapshots(nlevels=10)

# %% [markdown]
# As an illustration we plot the time series of the fifth best bid price and fifth best ask price throughout the simulation

# %%
## plotting fifth best bid and fifth best ask
times = [ t - ns_date(t) for t in L2["times"] ]
plt.scatter( times, L2["bids"][:,5,0], s=.5 )
plt.scatter( times, L2["asks"][:,5,0], s=.5 )

band = 100
plt.ylim(100_000-band,100_000+band)

_=plt.xticks(time_mesh, [ fmt_ts(time).split(" ")[1] for time in time_mesh], rotation=60 )

# %% [markdown]
# ### Looking at agents logs

# %% [markdown]
# All agents can be inspected to retrieve desired information.
# The utility parse_logs_df for instance provides a quick way to retrieve and aggregate the log variables of each agent in a single dataframe

# %%
logs_df = parse_logs_df( end_state )

# %% [markdown]
# #### Histogram of order submission times for noise agents

# %% [markdown]
# As an illustration we retrieve the submission times of all the orders sent by noise agent and display the histogram of all these times

# %%
plt.hist( logs_df[ (logs_df.agent_type == "NoiseAgent") & (logs_df.EventType=="ORDER_SUBMITTED") ].EventTime.apply(lambda x: x - ns_date(x) )  )

_=plt.xticks(time_mesh, [ fmt_ts(time).split(" ")[1] for time in time_mesh], rotation=60 )

# %% [markdown]
# We proceed the same way for value agents as well

# %%
plt.hist( logs_df[ (logs_df.agent_type == "ValueAgent") & (logs_df.EventType=="ORDER_SUBMITTED") ].EventTime.apply(lambda x: x - ns_date(x) )  )

_=plt.xticks(time_mesh, [ fmt_ts(time).split(" ")[1] for time in time_mesh], rotation=60 )
